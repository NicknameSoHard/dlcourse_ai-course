# %% [markdown]
# # Задание 4 - Перенос обучения (transfer learning) и тонкая настройка (fine-tuning)
#
# Одной из важнейшних техник в тренировке сетей - использовать заранее натренированные веса на более общей задачи в качестве начальной точки, а потом "дотренировать" их на конкретной.
#
# Такой подход и убыстряет обучение, и позволяет тренировать эффективные модели на маленьких наборах данных.
#
# В этом упражнении мы натренируем классификатор, который отличает хотдоги от не хотдогов!
# (более подробно - https://www.youtube.com/watch?v=ACmydtFDTGs)
#
# Это задание требует доступа к GPU, поэтому его можно выполнять либо на компьютере с GPU от NVidia, либо в [Google Colab](https://colab.research.google.com/).

# %% [markdown]
# Сначала давайте скачаем данные с картинками. Это сделает код в следующей ячейке. Данные будут разделены на две части. На обучающей выборке, которая будет храниться в папке **train_kaggle**, мы будем строить наши модели, а на тестовой выборке **test_kaggle** будем предсказывать класс, к которому относится фотография (хотдог или нет).
#
# ### Если вы в Google Colab!
#
# В нем можно запускать ноутбуки с доступом к GPU. Они не очень быстрые, зато бесплатные!
# Каждый ноутбук получает свой собственный environment c доступным диском итд.
#
# Через 90 минут отсуствия активности этот environment пропадает со всеми данными.
# Поэтому нам придется скачивать данные каждый раз.

# %%
import torch
from torchvision import models
from torch.utils.data import Dataset, SubsetRandomSampler
from torchvision import transforms

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os

# %%
from PIL import Image
import urllib
import json

# %%
device = torch.device("cuda:0") # Let's make sure GPU is available!
device
# Out:
# device(type='cuda', index=0)

# %%
# Download train data
# !wget "https://storage.googleapis.com/dlcourse_ai/train.zip"
# !unzip -q "train.zip"

# Download test data
# !wget "https://storage.googleapis.com/dlcourse_ai/test.zip"
# !unzip -q "test.zip"
# Out:
# --2020-01-16 15:13:35--  https://storage.googleapis.com/dlcourse_ai/train.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.212.128, 2607:f8b0:4001:c0e::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.212.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 562348083 (536M) [application/zip]
# Saving to: ‘train.zip’
#
# train.zip           100%[===================>] 536.30M   129MB/s    in 4.2s
#
# 2020-01-16 15:13:39 (129 MB/s) - ‘train.zip’ saved [562348083/562348083]
#
# --2020-01-16 15:13:46--  https://storage.googleapis.com/dlcourse_ai/test.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.112.128, 2607:f8b0:4001:c16::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.112.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 140788786 (134M) [application/zip]
# Saving to: ‘test.zip’
#
# test.zip            100%[===================>] 134.27M  52.7MB/s    in 2.5s
#
# 2020-01-16 15:13:48 (52.7 MB/s) - ‘test.zip’ saved [140788786/140788786]

# %%
train_folder = "train_kaggle/"
# Count number of files in the train folder, should be 4603
print('Number of files in the train folder', len(os.listdir(train_folder)))

test_folder = "test_kaggle/"
# Count number of files in the test folder, should be 1150
print('Number of files in the test folder', len(os.listdir(test_folder)))
# Out:
# Number of files in the train folder 4603
# Number of files in the test folder 1150

# %% [markdown]
# # Имплементируем свой Dataset для загрузки данных
#
# В этом задании мы реализуем свой собственный класс Dataset для загрузки данных. Его цель - загрузить данные с диска и выдать по ним тензор с входом сети, меткой и идентификатором картинки (так будет проще подготовить сабмит для kaggle на тестовых данных).
#
# Вот ссылка, где хорошо объясняется как это делать на примере: https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
#
# Ваш Dataset должен в качестве количества сэмплов выдать количество файлов в папке и уметь выдавать кортеж из сэмпла, метки по индексу и названия файла.
# Если название файла начинается со слов 'frankfurter', 'chili-dog' или 'hotdog' - метка положительная. Иначе отрицательная (ноль).
#
# И не забудьте поддержать возможность трансформации входа (аргумент `transforms`), она нам понадобится!

# %%
class HotdogOrNotDataset(Dataset):
    def __init__(self, folder, transform=None):
        self.root_dir = folder
        self.transform = transform

        self.sample_dict = {
            'frankfurter': 1,
            'chili-dog': 2,
            'hotdog': 3
        }

    def __len__(self):
        return len(os.listdir(self.root_dir))
    
    def __getitem__(self, index):        
        files = os.listdir(self.root_dir)
        
        img_id = files[index]

        img_full_name = os.path.join(self.root_dir, img_id)
        img = Image.open(img_full_name)

        sample_name = img_id.split('_')[0]
        y = 1 if self.sample_dict.get(sample_name, 0) else 0 

        if self.transform is not None:
          img = self.transform(img)

        return img, y, img_id

def visualize_samples(dataset, indices, title=None, count=10):
    # visualize random 10 samples
    plt.figure(figsize=(count*3,3))
    display_indices = indices[:count]
    if title:
        plt.suptitle("%s %s/%s" % (title, len(display_indices), len(indices)))        
    for i, index in enumerate(display_indices):    
        x, y, _ = dataset[index]
        plt.subplot(1,count,i+1)
        plt.title("Label: %s" % y)
        plt.imshow(x)
        plt.grid(False)
        plt.axis('off')   
    
orig_dataset = HotdogOrNotDataset(train_folder)
indices = np.random.choice(np.arange(len(orig_dataset)), 7, replace=False)

visualize_samples(orig_dataset, indices, "Samples")

# %%
# Let's make sure transforms work!
dataset = HotdogOrNotDataset(train_folder, transform=transforms.RandomVerticalFlip(0.9))

visualize_samples(dataset, indices, "Samples with flip - a lot should be flipped!")

# %% [markdown]
# # Создаем Dataset для тренировки
#
# И разделяем его на train и validation.
# На train будем обучать модель, на validation проверять ее качество, а соревнование Kaggle In-Class проведем на фотографиях из папки test_kaggle.

# %%
# First, lets load the dataset
train_dataset = HotdogOrNotDataset(train_folder, 
                       transform=transforms.Compose([
                           transforms.Resize((224, 224)),
                           transforms.ToTensor(),
                           # Use mean and std for pretrained models
                           # https://pytorch.org/docs/stable/torchvision/models.html
                           transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])                         
                       ])
                      )
test_dataset = HotdogOrNotDataset(test_folder, 
                       transform=transforms.Compose([
                           transforms.Resize((224, 224)),
                           transforms.ToTensor(),
                           # Use mean and std for pretrained models
                           # https://pytorch.org/docs/stable/torchvision/models.html
                           transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])                         
                       ])
                      )

# %%
batch_size = 64

data_size = len(dataset)
validation_fraction = .2

val_split = int(np.floor((validation_fraction) * data_size))
indices = list(range(data_size))
np.random.seed(42)
np.random.shuffle(indices)

val_indices, train_indices = indices[:val_split], indices[val_split:]

train_sampler = SubsetRandomSampler(train_indices)
val_sampler = SubsetRandomSampler(val_indices)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, 
                                           sampler=train_sampler)
val_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                         sampler=val_sampler)
# Notice that we create test data loader in a different way. We don't have the labels.
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size)

# %% [markdown]
# Наши обычные функции для тренировки

# %%
def train_model(model, train_loader, val_loader, loss, optimizer, num_epochs):    
    loss_history = []
    train_history = []
    val_history = []
    for epoch in range(num_epochs):
        model.train() # Enter train mode
        
        loss_accum = 0
        correct_samples = 0
        total_samples = 0
        for i_step, (x, y,_) in enumerate(train_loader):
            #print('Yes?')
            x_gpu = x.to(device)
            y_gpu = y.to(device)
            #print('Casted to device!')
            prediction = model(x_gpu)    
            #print('prediction!')
            loss_value = loss(prediction, y_gpu)
            #print('loss!')
            optimizer.zero_grad()
            #print('optimizer!')
            loss_value.backward()
            #print('backward!')
            optimizer.step()
            _, indices = torch.max(prediction, 1)
            correct_samples += torch.sum(indices == y_gpu)
            total_samples += y.shape[0]
            
            loss_accum += loss_value

        ave_loss = loss_accum / i_step
        train_accuracy = float(correct_samples) / total_samples
        val_accuracy = compute_accuracy(model, val_loader)
        
        loss_history.append(float(ave_loss))
        train_history.append(train_accuracy)
        val_history.append(val_accuracy)
        
        print("Average loss: %f, Train accuracy: %f, Val accuracy: %f" % (ave_loss, train_accuracy, val_accuracy))
        
    return loss_history, train_history, val_history
        
def compute_accuracy(model, loader):
    """
    Computes accuracy on the dataset wrapped in a loader
    
    Returns: accuracy as a float value between 0 and 1
    """
    model.eval() # Evaluation mode
    val_accuracy = 0
    correct = 0
    total = 0
        
    for i_step, (x, y, _) in enumerate(loader):
      x_gpu = x.to(device)
      y_gpu = y.to(device)

      pred = model(x_gpu)
      _, indices = torch.max(pred, 1)
      correct += torch.sum(indices == y_gpu)
      total += y_gpu.shape[0]

      val_accuracy = float(correct)/total
    
    return val_accuracy

# %% [markdown]
# # Использование заранее натренированной сети (pretrained network)
#
# Чаще всего в качестве заранее натренированной сети используется сеть, натренированная на данных ImageNet с 1M изображений и 1000 классами.
#
# PyTorch включает такие натренированные сети для различных архитектур (https://pytorch.org/docs/stable/torchvision/models.html)
# Мы будем использовать ResNet18.
#
# Для начала посмотрим, что выдает уже натренированная сеть на наших картинках. То есть, посмотрим к какому из 1000 классов их отнесет сеть.
#
# Запустите модель на 10 случайных картинках из датасета и выведите их вместе с классами с наибольшей вероятностью.
# В коде уже есть код, который формирует соответствие между индексами в выходном векторе и классами ImageNet.

# %%
# Thanks to https://discuss.pytorch.org/t/imagenet-classes/4923/2
def load_imagenet_classes():
    classes_json = urllib.request.urlopen('https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json').read()
    classes = json.loads(classes_json)
    
    # TODO: Process it to return dict of class index to name
    return { int(k): v[-1] for k, v in classes.items()}
    
model = models.resnet18(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/checkpoints/resnet18-5c106cde.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 209MB/s]

# %%
indices = np.random.choice(np.arange(len(orig_dataset)), 10, replace=False)
classes = load_imagenet_classes()

plt.figure(figsize=(10*3,3))
model.eval()
for ind, value in enumerate(indices):
    plt.subplot(1,10,ind+1)
    img, y, _ = train_dataset[value]
    img = img.unsqueeze(0)
    ans = model(img)
    _, ans = torch.max(ans, 1)
    plt.title(f"Predict as {classes[int(ans)]}")
    img, y, _ = dataset[value]
    plt.imshow(img)
    plt.grid(False)
    plt.axis('off')

# %% [markdown]
# # Перенос обучения (transfer learning) - тренировать только последний слой
#
# Существует несколько вариантов переноса обучения, мы попробуем основные.
# Первый вариант - заменить последний слой на новый и тренировать только его, заморозив остальные.

# %%
import torch.nn as nn
import torch.optim as optim

model = models.resnet18(pretrained=True)
for param in model.parameters():
    param.requires_grad = False

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model.type(torch.cuda.FloatTensor)
model.to(device)

parameters = model.fc.parameters()

loss = nn.CrossEntropyLoss().type(torch.cuda.FloatTensor)
optimizer = optim.SGD(parameters, lr=0.001, momentum=0.9)

loss_history, train_history, val_history = train_model(model, train_loader, 
                                                       val_loader, loss, 
                                                       optimizer, 2)
# Out:
# Average loss: 0.350694, Train accuracy: 0.847679, Val accuracy: 0.909783
# Average loss: 0.213414, Train accuracy: 0.918273, Val accuracy: 0.921739

# %% [markdown]
# # Перенос обучения (transfer learning) - тренировать всю модель
#
# Второй вариант - точно так же заменить последний слой на новый и обучать всю модель целиком.

# %%
import torch.nn as nn
import torch.optim as optim

model = models.resnet18(pretrained=True)
# TODO: Add a new output layer and train the whole model
# https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model.type(torch.cuda.FloatTensor)
model.to(device)

parameters = model.parameters()

loss = nn.CrossEntropyLoss()
optimizer = optim.SGD(parameters, lr=0.001, momentum=0.9)

loss_history, train_history, val_history = train_model(model, train_loader, 
                                                       val_loader, loss, 
                                                       optimizer, 2)
# Out:
# Average loss: 0.304055, Train accuracy: 0.859354, Val accuracy: 0.936957
# Average loss: 0.135646, Train accuracy: 0.954928, Val accuracy: 0.948913

# %% [markdown]
# # Перенос обучения (transfer learning) - разные скорости обучения для разных слоев
#
# И наконец последний вариант, который мы рассмотрим - использовать разные скорости обучения для новых и старых слоев

# %%
import torch.nn as nn
import torch.optim as optim

model = models.resnet18(pretrained=True)
loss = nn.CrossEntropyLoss()

num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 2)

model.type(torch.cuda.FloatTensor)
model.to(device)

parameters = [{'params': list(model.parameters())[:-1], 'lr': 1e-2},
              {'params': list(model.parameters())[-1:], 'lr': 1e-3}]

optimizer = optim.SGD(parameters, momentum=0.9)

loss_history, train_history, val_history = train_model(model, train_loader, 
                                                       val_loader, loss, 
                                                       optimizer, 2)
# Out:
# Average loss: 0.230585, Train accuracy: 0.908227, Val accuracy: 0.935870
# Average loss: 0.064341, Train accuracy: 0.973120, Val accuracy: 0.932609

# %% [markdown]
# # Визуализируем метрики и ошибки модели
#
# Попробуем посмотреть, где модель ошибается - визуализируем ложные срабатывания (false positives) и ложноотрицательные срабатывания (false negatives).
#
# Для этого мы прогоним модель через все примеры и сравним ее с истинными метками (ground truth).

# %%
from torch.utils.data.sampler import Sampler

class SubsetSampler(Sampler):
    r"""Samples elements with given indices sequentially

    Arguments:
        data_source (Dataset): dataset to sample from
        indices (ndarray): indices of the samples to take
    """

    def __init__(self, indices):
        self.indices = indices

    def __iter__(self):
        return (self.indices[i] for i in range(len(self.indices)))

    def __len__(self):
        return len(self.indices)
    
    
def evaluate_model(model, dataset, indices):
    """
    Computes predictions and ground truth labels for the indices of the dataset
    
    Returns: 
    predictions: np array of booleans of model predictions
    grount_truth: np array of boolean of actual labels of the dataset
    """
    model.eval() # Evaluation mode
    loader = torch.utils.data.DataLoader(dataset, 
                                         sampler=SubsetSampler(indices))
    predictions = []
    ground_truth = []
  
    for i_step, (x, y, _) in enumerate(loader):
        x_gpu = x.to(device)
        y_gpu = y.to(device)
        pred = model(x_gpu)
        _, indices = torch.max(pred, 1)
        predictions.append(int(indices))
        ground_truth.append(int(y_gpu))
    return predictions, ground_truth

predictions, gt = evaluate_model(model, train_dataset, val_indices)

# %% [markdown]
# И теперь можно визуализировать false positives и false negatives.

# %%
def get_fp_and_fn_samples(predictions, gt, val_indices):
  false_positive_indices = []
  false_negative_indices = []

  for ind, gts in enumerate(gt):
      if not gts and gts != predictions[ind]:
          false_positive_indices.append(val_indices[ind])
      if gts and gts != predictions[ind]:
          false_negative_indices.append(val_indices[ind])
  return false_positive_indices, false_negative_indices

# %%
false_positive_indices, false_negative_indices = \
                       get_fp_and_fn_samples(predictions, gt, val_indices)

visualize_samples(orig_dataset, false_positive_indices, "False positives")

visualize_samples(orig_dataset, false_negative_indices, "False negatives")

# %%
import sklearn.metrics as metrics

def binary_classification_metrics(prediction, ground_truth):
    b = 1

    true_positive = 0
    false_positive = 0
    true_negative = 0
    false_negative = 0

    for i in range(len(ground_truth)):
        if prediction[i] == ground_truth[i] == 1:
            true_positive += 1
        if ground_truth[i] == 1 and prediction[i] != ground_truth[i]:
            false_positive += 1
        if prediction[i] == ground_truth[i] == 0:
            true_negative += 1
        if ground_truth[i] == 0 and prediction[i] != ground_truth[i]:
            false_negative += 1
    try:
      precision = true_positive / (true_positive + false_positive)
      recall = true_positive / (true_positive + false_negative)
      accuracy = (true_positive + true_negative) / \
                (true_positive + true_negative + false_positive + false_negative)

      f1 = (1+b) * (precision * recall) / ((b**2 * precision) + recall)
      return precision, recall, f1, accuracy    
    except:
      return 0, 0, 0, 0


precision, recall, f1, _ = binary_classification_metrics(predictions, gt)
print("F1: %4.3f, P: %4.3f, R: %4.3f" % (f1, precision, recall))
# Out:
# F1: 0.891, P: 0.844, R: 0.944

# %% [markdown]
# # Что будет в конце вы уже поняли
#
# Натренируйте лучшую модель на основе `resnet18`, меняя только процесс тренировки.
# Выбирайте лучшую модель по F1 score.
#
# Как всегда, не забываем:
# - побольше аугментаций!
# - перебор гиперпараметров
# - различные оптимизаторы
# - какие слои тюнить
# - learning rate annealing
# - на какой эпохе останавливаться
#
# Наша цель - довести F1 score на validation set до значения, большего **0.91**.

# %%
from collections import namedtuple
Hyperparams = namedtuple("Hyperparams", 
                         ['learning_rate1', 'learning_rate2', 'anneal_epochs', 
                          'r1', 'r2', 'epochs'])

RunResult = namedtuple("RunResult", ['model', 'optimizer', 
                                     'train_history', 'val_history', 'f1_val'])
run_record = {}

# %%
import torch.nn as nn
import torch.optim as optim

epoch = 6
anneal_epochs = [1, 2]
reg = [1e-4, 1e-3, 1e-2]
lrs = [1e-2, 1e-3, 1e-4]

for ae in anneal_epochs:
  for r1 in reg:
    for r2 in reg:
      for lr1 in lrs:
        for lr2 in lrs:
          hprparams = Hyperparams(lr1, lr2, ae, r1, r2, epoch)
          print(hprparams)

          model = models.resnet18(pretrained=True)

          num_ftrs = model.fc.in_features
          model.fc = nn.Linear(num_ftrs, 2)
          model.type(torch.cuda.FloatTensor)
          model.to(device)

          parameters = [{'params': list(model.parameters())[:-1],
                         'lr':lr1, 'reg': r1}, 
                        {'params': list(model.parameters())[-1], 
                         'lr': lr2, 'reg': r2}]

          optimizer = optim.Adam(parameters)
          loss = nn.CrossEntropyLoss()
          loss_history, train_history, val_history = \
                                          train_model(model, train_loader, 
                                                      val_loader, loss, 
                                                      optimizer, epoch)
              
          predictions, gt = evaluate_model(model, train_dataset, val_indices)
          precision, recall, f1, _ = \
                              binary_classification_metrics(predictions, gt)

          score = RunResult(model, optimizer, train_history, val_history, f1)
          run_record[hprparams] = score
          print(f"f1: {score.f1_val}")
# Out:
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.795748, Train accuracy: 0.641053, Val accuracy: 0.672826
# Average loss: 0.589631, Train accuracy: 0.675536, Val accuracy: 0.672826
# Average loss: 0.529133, Train accuracy: 0.713006, Val accuracy: 0.684783
# Average loss: 0.509815, Train accuracy: 0.721151, Val accuracy: 0.711957
# Average loss: 0.473038, Train accuracy: 0.761879, Val accuracy: 0.751087
# Average loss: 0.500957, Train accuracy: 0.759435, Val accuracy: 0.702174
# 0.25136612021857924
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.813301, Train accuracy: 0.660060, Val accuracy: 0.672826
# Average loss: 0.632742, Train accuracy: 0.680695, Val accuracy: 0.672826
# Average loss: 0.586911, Train accuracy: 0.704317, Val accuracy: 0.718478
# Average loss: 0.521020, Train accuracy: 0.736628, Val accuracy: 0.678261
# Average loss: 0.523522, Train accuracy: 0.733098, Val accuracy: 0.717391
# Average loss: 0.485665, Train accuracy: 0.758349, Val accuracy: 0.766304
# 0.6737481031866464
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.893019, Train accuracy: 0.620418, Val accuracy: 0.672826
# Average loss: 0.637402, Train accuracy: 0.682324, Val accuracy: 0.672826
# Average loss: 0.556697, Train accuracy: 0.720880, Val accuracy: 0.706522
# Average loss: 0.514715, Train accuracy: 0.742058, Val accuracy: 0.677174
# Average loss: 0.463500, Train accuracy: 0.784686, Val accuracy: 0.751087
# Average loss: 0.450188, Train accuracy: 0.799891, Val accuracy: 0.698913
# 0.645326504481434
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.344682, Train accuracy: 0.856910, Val accuracy: 0.786957
# Average loss: 0.192388, Train accuracy: 0.924247, Val accuracy: 0.895652
# Average loss: 0.139984, Train accuracy: 0.948955, Val accuracy: 0.836957
# Average loss: 0.108427, Train accuracy: 0.960901, Val accuracy: 0.833696
# Average loss: 0.114206, Train accuracy: 0.957643, Val accuracy: 0.861957
# Average loss: 0.076906, Train accuracy: 0.969318, Val accuracy: 0.836957
# 0.7807017543859649
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.361677, Train accuracy: 0.854738, Val accuracy: 0.838043
# Average loss: 0.193849, Train accuracy: 0.920717, Val accuracy: 0.836957
# Average loss: 0.138524, Train accuracy: 0.945696, Val accuracy: 0.894565
# Average loss: 0.122026, Train accuracy: 0.952756, Val accuracy: 0.885870
# Average loss: 0.101044, Train accuracy: 0.960630, Val accuracy: 0.876087
# Average loss: 0.061445, Train accuracy: 0.979365, Val accuracy: 0.823913
# 0.6351351351351351
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.382750, Train accuracy: 0.838990, Val accuracy: 0.818478
# Average loss: 0.227272, Train accuracy: 0.908770, Val accuracy: 0.870652
# Average loss: 0.166528, Train accuracy: 0.931578, Val accuracy: 0.897826
# Average loss: 0.140172, Train accuracy: 0.946511, Val accuracy: 0.888043
# Average loss: 0.111808, Train accuracy: 0.959544, Val accuracy: 0.880435
# Average loss: 0.083552, Train accuracy: 0.970676, Val accuracy: 0.909783
# 0.8566493955094993
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.193957, Train accuracy: 0.924790, Val accuracy: 0.952174
# Average loss: 0.031026, Train accuracy: 0.992669, Val accuracy: 0.947826
# Average loss: 0.009145, Train accuracy: 0.998371, Val accuracy: 0.944565
# Average loss: 0.003107, Train accuracy: 0.999728, Val accuracy: 0.951087
# Average loss: 0.001352, Train accuracy: 1.000000, Val accuracy: 0.951087
# Average loss: 0.001183, Train accuracy: 1.000000, Val accuracy: 0.956522
# 0.9312714776632303
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.220455, Train accuracy: 0.908227, Val accuracy: 0.947826
# Average loss: 0.031127, Train accuracy: 0.992126, Val accuracy: 0.958696
# Average loss: 0.007837, Train accuracy: 0.999185, Val accuracy: 0.956522
# Average loss: 0.003168, Train accuracy: 0.999728, Val accuracy: 0.961957
# Average loss: 0.003470, Train accuracy: 0.999457, Val accuracy: 0.953261
# Average loss: 0.001216, Train accuracy: 1.000000, Val accuracy: 0.961957
# 0.9411764705882352
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.0001, epochs=6)
# Average loss: 0.205953, Train accuracy: 0.915829, Val accuracy: 0.923913
# Average loss: 0.031626, Train accuracy: 0.991854, Val accuracy: 0.947826
# Average loss: 0.005978, Train accuracy: 0.999728, Val accuracy: 0.959783
# Average loss: 0.004229, Train accuracy: 0.999728, Val accuracy: 0.956522
# Average loss: 0.001983, Train accuracy: 1.000000, Val accuracy: 0.955435
# Average loss: 0.001187, Train accuracy: 1.000000, Val accuracy: 0.958696
# 0.9358108108108107
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.761958, Train accuracy: 0.675808, Val accuracy: 0.677174
# Average loss: 0.609225, Train accuracy: 0.692642, Val accuracy: 0.710870
# Average loss: 0.559585, Train accuracy: 0.721151, Val accuracy: 0.721739
# Average loss: 0.480549, Train accuracy: 0.758078, Val accuracy: 0.707609
# Average loss: 0.458994, Train accuracy: 0.774097, Val accuracy: 0.758696
# Average loss: 0.431780, Train accuracy: 0.804507, Val accuracy: 0.782609
# 0.6825396825396826
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.720642, Train accuracy: 0.674722, Val accuracy: 0.672826
# Average loss: 0.583926, Train accuracy: 0.688026, Val accuracy: 0.661957
# Average loss: 0.580491, Train accuracy: 0.695086, Val accuracy: 0.486957
# Average loss: 0.584349, Train accuracy: 0.687483, Val accuracy: 0.678261
# Average loss: 0.508613, Train accuracy: 0.727668, Val accuracy: 0.544565
# Average loss: 0.476071, Train accuracy: 0.765680, Val accuracy: 0.619565
# 0.6195652173913043
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.807097, Train accuracy: 0.650828, Val accuracy: 0.672826
# Average loss: 0.589544, Train accuracy: 0.679881, Val accuracy: 0.672826
# Average loss: 0.569969, Train accuracy: 0.685311, Val accuracy: 0.655435
# Average loss: 0.526284, Train accuracy: 0.700787, Val accuracy: 0.677174
# Average loss: 0.558758, Train accuracy: 0.721423, Val accuracy: 0.671739
# Average loss: 0.539741, Train accuracy: 0.731740, Val accuracy: 0.734783
# 0.5611510791366907
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.364131, Train accuracy: 0.851480, Val accuracy: 0.845652
# Average loss: 0.207002, Train accuracy: 0.915558, Val accuracy: 0.846739
# Average loss: 0.167078, Train accuracy: 0.934021, Val accuracy: 0.884783
# Average loss: 0.140690, Train accuracy: 0.946783, Val accuracy: 0.789130
# Average loss: 0.093275, Train accuracy: 0.971762, Val accuracy: 0.902174
# Average loss: 0.053240, Train accuracy: 0.981808, Val accuracy: 0.822826
# 0.7757909215955984
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.385691, Train accuracy: 0.835732, Val accuracy: 0.863043
# Average loss: 0.194874, Train accuracy: 0.922074, Val accuracy: 0.913043
# Average loss: 0.144478, Train accuracy: 0.942438, Val accuracy: 0.886957
# Average loss: 0.094244, Train accuracy: 0.967689, Val accuracy: 0.833696
# Average loss: 0.094973, Train accuracy: 0.968775, Val accuracy: 0.867391
# Average loss: 0.099305, Train accuracy: 0.964431, Val accuracy: 0.855435
# 0.783739837398374
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.380584, Train accuracy: 0.847407, Val accuracy: 0.706522
# Average loss: 0.221018, Train accuracy: 0.909585, Val accuracy: 0.888043
# Average loss: 0.150972, Train accuracy: 0.942710, Val accuracy: 0.851087
# Average loss: 0.109761, Train accuracy: 0.957915, Val accuracy: 0.869565
# Average loss: 0.103304, Train accuracy: 0.960358, Val accuracy: 0.875000
# Average loss: 0.084117, Train accuracy: 0.971762, Val accuracy: 0.813043
# 0.6055045871559633
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.231216, Train accuracy: 0.908499, Val accuracy: 0.944565
# Average loss: 0.033232, Train accuracy: 0.990225, Val accuracy: 0.950000
# Average loss: 0.007147, Train accuracy: 0.999457, Val accuracy: 0.960870
# Average loss: 0.003027, Train accuracy: 1.000000, Val accuracy: 0.960870
# Average loss: 0.001965, Train accuracy: 1.000000, Val accuracy: 0.948913
# Average loss: 0.001506, Train accuracy: 1.000000, Val accuracy: 0.957609
# 0.9333333333333333
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.262231, Train accuracy: 0.895466, Val accuracy: 0.952174
# Average loss: 0.035525, Train accuracy: 0.989954, Val accuracy: 0.953261
# Average loss: 0.010845, Train accuracy: 0.998371, Val accuracy: 0.952174
# Average loss: 0.007781, Train accuracy: 0.997828, Val accuracy: 0.947826
# Average loss: 0.003925, Train accuracy: 1.000000, Val accuracy: 0.953261
# Average loss: 0.002205, Train accuracy: 0.999457, Val accuracy: 0.955435
# 0.9303904923599321
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.001, epochs=6)
# Average loss: 0.255553, Train accuracy: 0.892750, Val accuracy: 0.917391
# Average loss: 0.038943, Train accuracy: 0.989411, Val accuracy: 0.946739
# Average loss: 0.009337, Train accuracy: 0.998371, Val accuracy: 0.961957
# Average loss: 0.009349, Train accuracy: 0.998099, Val accuracy: 0.948913
# Average loss: 0.008755, Train accuracy: 0.998099, Val accuracy: 0.957609
# Average loss: 0.008902, Train accuracy: 0.997556, Val accuracy: 0.957609
# 0.9367909238249595
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.702721, Train accuracy: 0.685039, Val accuracy: 0.672826
# Average loss: 0.601704, Train accuracy: 0.699701, Val accuracy: 0.685870
# Average loss: 0.555949, Train accuracy: 0.715721, Val accuracy: 0.671739
# Average loss: 0.505223, Train accuracy: 0.731740, Val accuracy: 0.597826
# Average loss: 0.486853, Train accuracy: 0.752919, Val accuracy: 0.719565
# Average loss: 0.526700, Train accuracy: 0.719794, Val accuracy: 0.711957
# 0.6324549237170596
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.871529, Train accuracy: 0.631279, Val accuracy: 0.672826
# Average loss: 0.722980, Train accuracy: 0.682867, Val accuracy: 0.672826
# Average loss: 0.685100, Train accuracy: 0.682324, Val accuracy: 0.672826
# Average loss: 0.665765, Train accuracy: 0.683139, Val accuracy: 0.663043
# Average loss: 0.654226, Train accuracy: 0.687483, Val accuracy: 0.672826
# Average loss: 0.644237, Train accuracy: 0.689112, Val accuracy: 0.672826
# 0
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.714988, Train accuracy: 0.653543, Val accuracy: 0.672826
# Average loss: 0.576783, Train accuracy: 0.697529, Val accuracy: 0.668478
# Average loss: 0.650841, Train accuracy: 0.706761, Val accuracy: 0.672826
# Average loss: 0.656286, Train accuracy: 0.686668, Val accuracy: 0.689130
# Average loss: 0.519919, Train accuracy: 0.717350, Val accuracy: 0.733696
# Average loss: 0.482834, Train accuracy: 0.761607, Val accuracy: 0.765217
# 0.6516129032258065
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.378156, Train accuracy: 0.850937, Val accuracy: 0.850000
# Average loss: 0.195072, Train accuracy: 0.918002, Val accuracy: 0.867391
# Average loss: 0.133706, Train accuracy: 0.945696, Val accuracy: 0.877174
# Average loss: 0.121340, Train accuracy: 0.953027, Val accuracy: 0.860870
# Average loss: 0.089441, Train accuracy: 0.966603, Val accuracy: 0.884783
# Average loss: 0.070930, Train accuracy: 0.975835, Val accuracy: 0.885870
# 0.8180242634315424
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.388385, Train accuracy: 0.843877, Val accuracy: 0.791304
# Average loss: 0.201230, Train accuracy: 0.920988, Val accuracy: 0.853261
# Average loss: 0.143060, Train accuracy: 0.947054, Val accuracy: 0.877174
# Average loss: 0.120057, Train accuracy: 0.955200, Val accuracy: 0.872826
# Average loss: 0.093722, Train accuracy: 0.965517, Val accuracy: 0.871739
# Average loss: 0.100207, Train accuracy: 0.960901, Val accuracy: 0.881522
# 0.8084358523725835
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.363032, Train accuracy: 0.850122, Val accuracy: 0.868478
# Average loss: 0.198068, Train accuracy: 0.921531, Val accuracy: 0.884783
# Average loss: 0.149574, Train accuracy: 0.946511, Val accuracy: 0.892391
# Average loss: 0.119688, Train accuracy: 0.955471, Val accuracy: 0.877174
# Average loss: 0.084923, Train accuracy: 0.969590, Val accuracy: 0.863043
# Average loss: 0.093659, Train accuracy: 0.965246, Val accuracy: 0.883696
# 0.831496062992126
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.204649, Train accuracy: 0.918816, Val accuracy: 0.948913
# Average loss: 0.030966, Train accuracy: 0.992126, Val accuracy: 0.941304
# Average loss: 0.007507, Train accuracy: 0.999185, Val accuracy: 0.947826
# Average loss: 0.004675, Train accuracy: 0.999457, Val accuracy: 0.947826
# Average loss: 0.003968, Train accuracy: 0.999457, Val accuracy: 0.948913
# Average loss: 0.001548, Train accuracy: 1.000000, Val accuracy: 0.947826
# 0.9189189189189191
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.220839, Train accuracy: 0.908499, Val accuracy: 0.940217
# Average loss: 0.036534, Train accuracy: 0.990768, Val accuracy: 0.930435
# Average loss: 0.011055, Train accuracy: 0.997828, Val accuracy: 0.954348
# Average loss: 0.004216, Train accuracy: 1.000000, Val accuracy: 0.947826
# Average loss: 0.002011, Train accuracy: 1.000000, Val accuracy: 0.946739
# Average loss: 0.003445, Train accuracy: 0.999185, Val accuracy: 0.945652
# 0.9155405405405406
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.0001, r2=0.01, epochs=6)
# Average loss: 0.206029, Train accuracy: 0.915286, Val accuracy: 0.950000
# Average loss: 0.034880, Train accuracy: 0.991040, Val accuracy: 0.956522
# Average loss: 0.007991, Train accuracy: 1.000000, Val accuracy: 0.959783
# Average loss: 0.003478, Train accuracy: 1.000000, Val accuracy: 0.948913
# Average loss: 0.002210, Train accuracy: 1.000000, Val accuracy: 0.953261
# Average loss: 0.001125, Train accuracy: 1.000000, Val accuracy: 0.953261
# 0.9259896729776248
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.748518, Train accuracy: 0.669563, Val accuracy: 0.672826
# Average loss: 0.596972, Train accuracy: 0.695900, Val accuracy: 0.679348
# Average loss: 0.531718, Train accuracy: 0.724681, Val accuracy: 0.718478
# Average loss: 0.522568, Train accuracy: 0.735270, Val accuracy: 0.672826
# Average loss: 0.494252, Train accuracy: 0.741515, Val accuracy: 0.743478
# Average loss: 0.482088, Train accuracy: 0.756992, Val accuracy: 0.680435
# 0.45555555555555555
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.728451, Train accuracy: 0.666305, Val accuracy: 0.672826
# Average loss: 0.584787, Train accuracy: 0.675265, Val accuracy: 0.672826
# Average loss: 0.595769, Train accuracy: 0.675265, Val accuracy: 0.672826
# Average loss: 0.565335, Train accuracy: 0.689112, Val accuracy: 0.678261
# Average loss: 0.508791, Train accuracy: 0.723595, Val accuracy: 0.703261
# Average loss: 0.480133, Train accuracy: 0.754548, Val accuracy: 0.686957
# 0.6595744680851063
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.719722, Train accuracy: 0.658702, Val accuracy: 0.608696
# Average loss: 0.583091, Train accuracy: 0.693728, Val accuracy: 0.646739
# Average loss: 0.542461, Train accuracy: 0.700244, Val accuracy: 0.695652
# Average loss: 0.515527, Train accuracy: 0.734184, Val accuracy: 0.553261
# Average loss: 0.516038, Train accuracy: 0.751833, Val accuracy: 0.754348
# Average loss: 0.454245, Train accuracy: 0.782243, Val accuracy: 0.740217
# 0.6224328593996841
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.361137, Train accuracy: 0.854195, Val accuracy: 0.761957
# Average loss: 0.213914, Train accuracy: 0.913929, Val accuracy: 0.857609
# Average loss: 0.155836, Train accuracy: 0.938637, Val accuracy: 0.852174
# Average loss: 0.114384, Train accuracy: 0.958458, Val accuracy: 0.839130
# Average loss: 0.125471, Train accuracy: 0.957372, Val accuracy: 0.865217
# Average loss: 0.072889, Train accuracy: 0.971762, Val accuracy: 0.738043
# 0.7106842737094837
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.375328, Train accuracy: 0.849308, Val accuracy: 0.876087
# Average loss: 0.216819, Train accuracy: 0.915286, Val accuracy: 0.890217
# Average loss: 0.148700, Train accuracy: 0.943796, Val accuracy: 0.857609
# Average loss: 0.121850, Train accuracy: 0.956014, Val accuracy: 0.885870
# Average loss: 0.113034, Train accuracy: 0.959001, Val accuracy: 0.870652
# Average loss: 0.077050, Train accuracy: 0.974477, Val accuracy: 0.853261
# 0.7145877378435518
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.341944, Train accuracy: 0.859082, Val accuracy: 0.780435
# Average loss: 0.171574, Train accuracy: 0.929948, Val accuracy: 0.891304
# Average loss: 0.161400, Train accuracy: 0.938637, Val accuracy: 0.884783
# Average loss: 0.116048, Train accuracy: 0.956829, Val accuracy: 0.881522
# Average loss: 0.101198, Train accuracy: 0.963617, Val accuracy: 0.884783
# Average loss: 0.062136, Train accuracy: 0.974749, Val accuracy: 0.891304
# 0.8181818181818182
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.201920, Train accuracy: 0.918816, Val accuracy: 0.953261
# Average loss: 0.033367, Train accuracy: 0.989411, Val accuracy: 0.958696
# Average loss: 0.006865, Train accuracy: 0.999457, Val accuracy: 0.958696
# Average loss: 0.003183, Train accuracy: 0.999728, Val accuracy: 0.951087
# Average loss: 0.001868, Train accuracy: 1.000000, Val accuracy: 0.954348
# Average loss: 0.001657, Train accuracy: 0.999728, Val accuracy: 0.947826
# 0.9172413793103448
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.287409, Train accuracy: 0.888949, Val accuracy: 0.934783
# Average loss: 0.045205, Train accuracy: 0.985881, Val accuracy: 0.946739
# Average loss: 0.010107, Train accuracy: 0.999185, Val accuracy: 0.952174
# Average loss: 0.003894, Train accuracy: 1.000000, Val accuracy: 0.956522
# Average loss: 0.002446, Train accuracy: 1.000000, Val accuracy: 0.956522
# Average loss: 0.001483, Train accuracy: 1.000000, Val accuracy: 0.955435
# 0.9294320137693632
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.0001, epochs=6)
# Average loss: 0.226131, Train accuracy: 0.910399, Val accuracy: 0.946739
# Average loss: 0.037163, Train accuracy: 0.990225, Val accuracy: 0.953261
# Average loss: 0.006626, Train accuracy: 0.999457, Val accuracy: 0.956522
# Average loss: 0.004537, Train accuracy: 0.999457, Val accuracy: 0.958696
# Average loss: 0.002391, Train accuracy: 1.000000, Val accuracy: 0.958696
# Average loss: 0.001662, Train accuracy: 1.000000, Val accuracy: 0.957609
# 0.9342327150084317
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.779301, Train accuracy: 0.655444, Val accuracy: 0.582609
# Average loss: 0.572396, Train accuracy: 0.699158, Val accuracy: 0.672826
# Average loss: 0.517301, Train accuracy: 0.721423, Val accuracy: 0.700000
# Average loss: 0.509589, Train accuracy: 0.721151, Val accuracy: 0.695652
# Average loss: 0.507510, Train accuracy: 0.752104, Val accuracy: 0.600000
# Average loss: 0.475265, Train accuracy: 0.760521, Val accuracy: 0.751087
# 0.6676342525399129
# Hyperparams(learning_rate1=0.01, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.775420, Train accuracy: 0.672821, Val accuracy: 0.672826
# Average loss: 0.597685, Train accuracy: 0.692099, Val accuracy: 0.632609
# Average loss: 0.542414, Train accuracy: 0.710562, Val accuracy: 0.645652
# Average loss: 0.519290, Train accuracy: 0.726039, Val accuracy: 0.684783
# Average loss: 0.500383, Train accuracy: 0.728754, Val accuracy: 0.743478
# Average loss: 0.606095, Train accuracy: 0.697801, Val accuracy: 0.665217
# 0.019108280254777066
# Hyperparams(learning_rate1=0.01, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.862876, Train accuracy: 0.683139, Val accuracy: 0.672826
# Average loss: 0.652062, Train accuracy: 0.668477, Val accuracy: 0.679348
# Average loss: 0.544761, Train accuracy: 0.697801, Val accuracy: 0.693478
# Average loss: 0.526193, Train accuracy: 0.721966, Val accuracy: 0.684783
# Average loss: 0.485298, Train accuracy: 0.746131, Val accuracy: 0.726087
# Average loss: 0.486864, Train accuracy: 0.734184, Val accuracy: 0.603261
# 0.6137566137566138
# Hyperparams(learning_rate1=0.001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.341745, Train accuracy: 0.866413, Val accuracy: 0.875000
# Average loss: 0.185639, Train accuracy: 0.924790, Val accuracy: 0.890217
# Average loss: 0.149299, Train accuracy: 0.942438, Val accuracy: 0.873913
# Average loss: 0.125968, Train accuracy: 0.953027, Val accuracy: 0.880435
# Average loss: 0.069660, Train accuracy: 0.976649, Val accuracy: 0.881522
# Average loss: 0.068830, Train accuracy: 0.976106, Val accuracy: 0.875000
# 0.8142164781906301
# Hyperparams(learning_rate1=0.001, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.361214, Train accuracy: 0.847950, Val accuracy: 0.861957
# Average loss: 0.194214, Train accuracy: 0.923975, Val accuracy: 0.879348
# Average loss: 0.135369, Train accuracy: 0.948683, Val accuracy: 0.852174
# Average loss: 0.124256, Train accuracy: 0.949226, Val accuracy: 0.879348
# Average loss: 0.099629, Train accuracy: 0.964974, Val accuracy: 0.895652
# Average loss: 0.064217, Train accuracy: 0.978822, Val accuracy: 0.880435
# 0.7900763358778625
# Hyperparams(learning_rate1=0.001, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.367100, Train accuracy: 0.862612, Val accuracy: 0.788043
# Average loss: 0.184313, Train accuracy: 0.933207, Val accuracy: 0.860870
# Average loss: 0.150625, Train accuracy: 0.940809, Val accuracy: 0.801087
# Average loss: 0.103269, Train accuracy: 0.961988, Val accuracy: 0.905435
# Average loss: 0.075940, Train accuracy: 0.972034, Val accuracy: 0.879348
# Average loss: 0.076824, Train accuracy: 0.972034, Val accuracy: 0.886957
# 0.8343949044585988
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.219061, Train accuracy: 0.907141, Val accuracy: 0.955435
# Average loss: 0.035417, Train accuracy: 0.990768, Val accuracy: 0.953261
# Average loss: 0.006857, Train accuracy: 0.998914, Val accuracy: 0.956522
# Average loss: 0.004600, Train accuracy: 1.000000, Val accuracy: 0.953261
# Average loss: 0.002007, Train accuracy: 1.000000, Val accuracy: 0.951087
# Average loss: 0.001574, Train accuracy: 1.000000, Val accuracy: 0.955435
# 0.9303904923599321
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.218976, Train accuracy: 0.909042, Val accuracy: 0.944565
# Average loss: 0.043828, Train accuracy: 0.986153, Val accuracy: 0.950000
# Average loss: 0.010823, Train accuracy: 0.998099, Val accuracy: 0.956522
# Average loss: 0.003158, Train accuracy: 1.000000, Val accuracy: 0.950000
# Average loss: 0.001658, Train accuracy: 1.000000, Val accuracy: 0.950000
# Average loss: 0.001613, Train accuracy: 1.000000, Val accuracy: 0.952174
# 0.9249146757679182
# Hyperparams(learning_rate1=0.0001, learning_rate2=0.0001, anneal_epochs=1, r1=0.001, r2=0.001, epochs=6)
# Average loss: 0.215903, Train accuracy: 0.913929, Val accuracy: 0.943478
# Average loss: 0.041032, Train accuracy: 0.990225, Val accuracy: 0.940217
# Average loss: 0.009251, Train accuracy: 0.998914, Val accuracy: 0.947826
# Average loss: 0.003155, Train accuracy: 0.999728, Val accuracy: 0.952174
# Average loss: 0.003381, Train accuracy: 0.999728, Val accuracy: 0.953261
# Average loss: 0.002063, Train accuracy: 1.000000, Val accuracy: 0.945652
# 0.912280701754386
# Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)
# Average loss: 0.858441, Train accuracy: 0.652186, Val accuracy: 0.672826
# Average loss: 0.604300, Train accuracy: 0.692099, Val accuracy: 0.677174
# Average loss: 0.539016, Train accuracy: 0.696715, Val accuracy: 0.672826
# Average loss: 0.518941, Train accuracy: 0.724681, Val accuracy: 0.672826

# %%
best_model = None
best_val_f1 = None
best_hyperparams = None
best_run = None

for hyperparams, run_result in run_record.items():
    if best_val_f1 is None or best_val_f1 < run_result.f1_val:
        best_val_f1 = run_result.f1_val
        best_hyperparams = hyperparams
        best_run = run_result 
        best_model = run_result.model

print("Best validation f1: %4.2f, best hyperparams: %s" % (best_val_f1, best_hyperparams))
# Out:
# Best validation f1: 0.91, best hyperparams: Hyperparams(learning_rate1=0.01, learning_rate2=0.01, anneal_epochs=1, r1=0.001, r2=0.01, epochs=6)

# %% [markdown]
# # Необязательное задание с большой звездочкой
#
# Поучавствуйте в Kaggle In-Class Hot Dog Recognition Challenge!
# Это соревнование сделано специально для курса и в нем учавствуют только те, кто проходит курс.
#
# В нем участники соревнуются в качестве натренированных моделей, загружая на сайт предсказания своих моделей на тестовой выборке. Разметка тестовой выборке участникам недоступна.
# Более подробно о правилах соревнования ниже.
#
# Те, кто проходят курс лично, за высокое место в соревновании получат дополнительные баллы.
#
# Здесь уже можно использовать и другие базовые архитектуры кроме `resnet18`, и ансамбли, и другие трюки тренировки моделей.
#
# Вот ссылка на соревнование:
# https://www.kaggle.com/c/hotdogornot

# %%
image_id = []
predictions = []
model.eval()
for x,_,id_img in test_loader:
    # TODO : Напишите код для предсказания меток (1 = есть хотдог, 0 = хотдога нет)
    # Код должен возвратить список из id картинки и метку predictions
    # image id - это название файла картинки, например '10000.jpg'
    pass

# %%
# Так можно создать csv файл, чтобы затем загрузить его на kaggle
# Ожидаемый формат csv-файла:
# image_id,label
# 10000.jpg,1
# 10001.jpg,1
# 10002.jpg,0
# 10003.jpg,1
# 10004.jpg,0

with open('subm.csv', 'w') as submissionFile:
    writer = csv.writer(submissionFile)
    writer.writerow(['image_id', 'label'])
    writer.writerows(zip(image_id,predictions))

# %%
# А так можно скачать файл с Google Colab
files.download('subm.csv')

# %% [markdown]
# ### Небольшое введение в Kaggle для тех, кто не слышал об этой платформе раньше

# %% [markdown]
# В основе своей Kaggle - это платформа для проведения соревнований по машинному обучению. Появилась она в 2010 и, пожалуй, стала самой популярной и известной из всех существующих площадок по машинному обучению. Надо сказать, что Kaggle - это не только соревнования, но и сообщество людей, увлеченных машинным обучением. А судя по Википедии, в 2017 году отметка зарегистрированных пользователей перевалила за миллион. Есть там и обучающие материалы, возможность задавать вопросы, делиться кодом и идеями - просто мечта.
#
# ### Как проходят соревнования?
# Обычно участники скачивают данные для обучения моделей (train data), чтобы затем делать предсказания на тестовых данных (test data). Обучающая выборка содержит как сами данные, так и правильные метки (значения зависимой переменной), чтобы можно было обучить модель. Но тестовые данные ответа не содержат - и нашей целью является предсказание меток по имеющимся данным. Файл с ответами для каждого наблюдения из тестовой выборки загружается на Kaggle и оценивается в соответствии с выбранной метрикой соревнования, а результат является публичным и показывается в общей таблице (ее называют еще лидербордом - leaderboard) - чтобы появилось желание посоревноваться и создать еще более сильную модель. В "настоящих" соревнованиях, которые проходят на Kaggle, есть и денежное вознаграждение для тех участников, кто занимает первые места на лидерборде. Например, в [этом](https://www.kaggle.com/c/zillow-prize-1#description) соревновании, человек, занявший первое место, получил около 1 000 000 долларов.
#
# Тестовые данные делятся случайным образом в некоторой пропорции. И пока соревнование идет, на лидерборде показываются очки и рейтинг участников только по одной части (Public Leaderboard). А вот когда соревнование заканчивается, то рейтинг участников составляется по второй части тестовых данных (Private Leaderboard). И часто можно видеть, как люди занимавшие первые места на публичной части тестовых данных, оказываются далеко не первыми на закрытой части тестовых данных. Зачем это сделано? Есть несколько причин, но, пожалуй, самой фундаментальной является идея недообучения-переобучения. Всегда возможно, что наша модель настроилась на конкретную выборку, но как она поведет себя на тех данных, которые еще не видела? Разбиение тестовых данных на публичную и скрытую части сделано для того, чтобы отобрать модели, которые имеют большую обобщающую способность. Одним из лозунгов участников соревнований стал "Доверяйте своей локальной кросс-валидации" (Trust your CV!). Есть очень большой соблазн оценивать свою модель по публичной части лидерборда, но лучшей стратегией будет выбирать ту модель, которая дает лучшую метрику на кросс-валидации на обучающей выборке.
#
# В нашем соревновании публичная часть лидерборда составляет 30%, а скрытая 70%. Вы можете делать до двух попыток в день, а оцениваться попытки будут по F1-мере. Удачи и доверяйте своей локальной валидации! В конце соревнования у вас будет возможность выбрать 2 из всех совершенных попыток - лучшая из этих двух и будет засчитана вам на скрытой части тестовых данных.
